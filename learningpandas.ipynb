# %%
import pandas as pd

data = {
    'Component': ['CPU', 'GPU', 'RAM', 'Motherboard', 'SSD'],
    'Name': ['Ryzen 5 7600', 'RTX 4060', 'Corsair 32GB', 'B650 Tomahawk', 'Samsung 1TB'],
    'Price_SR': [850, 1200, 450, 800, 350]
}
df=pd.DataFrame(data)
display(df)
# Out:
#      Component           Name  Price_SR
# 0          CPU   Ryzen 5 7600       850
# 1          GPU       RTX 4060      1200
# 2          RAM   Corsair 32GB       450
# 3  Motherboard  B650 Tomahawk       800
# 4          SSD    Samsung 1TB       350
